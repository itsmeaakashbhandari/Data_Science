# %% [markdown]
# # PANDAS
# module to manipulate data. It behaves actually like Excel

# %%
import pandas  as pd

# %%
import numpy as np

# %%
#load data
#iris=object
iris=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
iris
#it using 1 st row as a header
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
print(type(iris))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#dataframe- 2d table with rows and columns

# %%
#copy of original dataframe
df=iris.copy()

# %%
#print few initial elements
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.head(10)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa
# 7  4.4  2.9  1.4  0.2  Iris-setosa
# 8  4.9  3.1  1.5  0.1  Iris-setosa
# 9  5.4  3.7  1.5  0.2  Iris-setosa

# %%
print(df.shape)
# Out:
# (149, 5)

# %%
print(df.dtypes)
# Out:
# 5.1            float64
# 3.5            float64
# 1.4            float64
# 0.2            float64
# Iris-setosa     object
# dtype: object

# %% [markdown]
# ## Change the column Headers

# %%
df.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
#columns changing statement
df.columns=['sl','sw','pl','pw','flower_type']

# %%
print(df.dtypes)
# Out:
# sl             float64
# sw             float64
# pl             float64
# pw             float64
# flower_type     object
# dtype: object

# %%
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
#show informative things about dataframe (count , mean , max, min)
df.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
#from count we got to know that we have all the data . if there is missing then it will show some(NaN)

# %%
#to access particular column
df.sl
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sl, Length: 149, dtype: float64

# %%
df['sl']
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sl, Length: 149, dtype: float64

# %%
#to find null entry
df.isnull()
# Out:
#         sl     sw     pl     pw  flower_type
# 0    False  False  False  False        False
# 1    False  False  False  False        False
# 2    False  False  False  False        False
# 3    False  False  False  False        False
# 4    False  False  False  False        False
# ..     ...    ...    ...    ...          ...
# 144  False  False  False  False        False
# 145  False  False  False  False        False
# 146  False  False  False  False        False
# 147  False  False  False  False        False
# 148  False  False  False  False        False
#
# [149 rows x 5 columns]

# %%
#it shows the sum of null entry column wise
df.isnull().sum()
# Out:
# sl             0
# sw             0
# pl             0
# pw             0
# flower_type    0
# dtype: int64

# %%
#access some  particular data, slice using ILOC fabsunction
df.iloc[1:4, 2:3]
# Out:
#     pl
# 1  1.3
# 2  1.5
# 3  1.4

# %% [markdown]
# # MANIPULATING DATA IN DATA FRAME

# %% [markdown]
# ## Remove rows by label and position

# %%
#Drop by label
#to remove 0 from label(S.No.)
df.drop(0,inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17444/63517554.py in <module>
#       1 #Drop by label
#       2 #to remove 0 from label(S.No.)
# ----> 3 df.drop(0,inplace=True)
#       4 df.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df.drop(3,inplace=True)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa

# %%
#to print labels
df.index
# Out:
# Int64Index([  1,   2,   4,   5,   6,   7,   8,   9,  10,  11,
#             ...
#             139, 140, 141, 142, 143, 144, 145, 146, 147, 148],
#            dtype='int64', length=147)

# %%
#Drop by position
df.drop(df.index[0], inplace=True)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa
# 7  4.4  2.9  1.4  0.2  Iris-setosa

# %% [markdown]
# ### Print row by condition

# %%
#condition 
df.sl>5
# Out:
# 2      False
# 4       True
# 5      False
# 6      False
# 7      False
#        ...
# 144     True
# 145     True
# 146     True
# 147     True
# 148     True
# Name: sl, Length: 146, dtype: bool

# %%
#to print only those row whosee condition is true
df[df.sl>5]
# Out:
#       sl   sw   pl   pw     flower_type
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# 9    5.4  3.7  1.5  0.2     Iris-setosa
# 13   5.8  4.0  1.2  0.2     Iris-setosa
# 14   5.7  4.4  1.5  0.4     Iris-setosa
# 15   5.4  3.9  1.3  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [117 rows x 5 columns]

# %%
df[df.flower_type=='Iris-setosa']
# Out:
#      sl   sw   pl   pw  flower_type
# 2   4.6  3.1  1.5  0.2  Iris-setosa
# 4   5.4  3.9  1.7  0.4  Iris-setosa
# 5   4.6  3.4  1.4  0.3  Iris-setosa
# 6   5.0  3.4  1.5  0.2  Iris-setosa
# 7   4.4  2.9  1.4  0.2  Iris-setosa
# 8   4.9  3.1  1.5  0.1  Iris-setosa
# 9   5.4  3.7  1.5  0.2  Iris-setosa
# 10  4.8  3.4  1.6  0.2  Iris-setosa
# 11  4.8  3.0  1.4  0.1  Iris-setosa
# 12  4.3  3.0  1.1  0.1  Iris-setosa
# 13  5.8  4.0  1.2  0.2  Iris-setosa
# 14  5.7  4.4  1.5  0.4  Iris-setosa
# 15  5.4  3.9  1.3  0.4  Iris-setosa
# 16  5.1  3.5  1.4  0.3  Iris-setosa
# 17  5.7  3.8  1.7  0.3  Iris-setosa
# 18  5.1  3.8  1.5  0.3  Iris-setosa
# 19  5.4  3.4  1.7  0.2  Iris-setosa
# 20  5.1  3.7  1.5  0.4  Iris-setosa
# 21  4.6  3.6  1.0  0.2  Iris-setosa
# 22  5.1  3.3  1.7  0.5  Iris-setosa
# 23  4.8  3.4  1.9  0.2  Iris-setosa
# 24  5.0  3.0  1.6  0.2  Iris-setosa
# 25  5.0  3.4  1.6  0.4  Iris-setosa
# 26  5.2  3.5  1.5  0.2  Iris-setosa
# 27  5.2  3.4  1.4  0.2  Iris-setosa
# ...

# %%
#with describe
df[df.flower_type=='Iris-setosa'].describe()
# Out:
#               sl         sw         pl         pw
# count  46.000000  46.000000  46.000000  46.000000
# mean    5.013043   3.426087   1.471739   0.247826
# std     0.364301   0.390120   0.178466   0.111034
# min     4.300000   2.300000   1.000000   0.100000
# 25%     4.800000   3.125000   1.400000   0.200000
# 50%     5.000000   3.400000   1.500000   0.200000
# 75%     5.200000   3.700000   1.600000   0.300000
# max     5.800000   4.400000   1.900000   0.600000

# %%
#ILOC vs LOC
print(df.head())
print(df.iloc[0]) #[position]
(df.loc[5])  #[label]
# Out:
#     sl   sw   pl   pw  flower_type
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa
# 7  4.4  2.9  1.4  0.2  Iris-setosa
# sl                     4.6
# sw                     3.1
# pl                     1.5
# pw                     0.2
# flower_type    Iris-setosa
# Name: 2, dtype: object
# sl                     4.6
# sw                     3.4
# pl                     1.4
# pw                     0.3
# flower_type    Iris-setosa
# Name: 5, dtype: object

# %% [markdown]
# ## Add a row

# %%
#it add the row at the end
df.loc[0]=[1,2,3,4,'Iris-setosa']

# %%
df.tail()
# Out:
#       sl   sw   pl   pw     flower_type
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
# 0    1.0  2.0  3.0  4.0     Iris-setosa

# %%
df.index
# Out:
# Int64Index([  2,   4,   5,   6,   7,   8,   9,  10,  11,  12,
#             ...
#             140, 141, 142, 143, 144, 145, 146, 147, 148,   0],
#            dtype='int64', length=147)

# %% [markdown]
# ## Reset index

# %%
#REST INDEX
df.reset_index(drop=True, inplace=True)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=147, step=1)

# %%
#to drop sl COLUMN 
df.drop('sl',axis=1)
# Out:
#       pl   pw     flower_type
# 0    1.5  0.2     Iris-setosa
# 1    1.7  0.4     Iris-setosa
# 2    1.4  0.3     Iris-setosa
# 3    1.5  0.2     Iris-setosa
# 4    1.4  0.2     Iris-setosa
# ..   ...  ...             ...
# 142  5.0  1.9  Iris-virginica
# 143  5.2  2.0  Iris-virginica
# 144  5.4  2.3  Iris-virginica
# 145  5.1  1.8  Iris-virginica
# 146  3.0  4.0     Iris-setosa
#
# [147 rows x 3 columns]

# %%
df.describe()
# Out:
#                sl          sw          pl          pw
# count  147.000000  147.000000  147.000000  147.000000
# mean     5.835374    3.039456    3.818367    1.244898
# std      0.914705    0.442372    1.738328    0.786546
# min      1.000000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.350000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    4.000000

# %%
#delete sw column
del df['sw']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sw'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.describe()
# Out:
#                sl          pl          pw
# count  147.000000  147.000000  147.000000
# mean     5.835374    3.818367    1.244898
# std      0.914705    1.738328    0.786546
# min      1.000000    1.000000    0.100000
# 25%      5.100000    1.600000    0.350000
# 50%      5.800000    4.400000    1.300000
# 75%      6.400000    5.100000    1.800000
# max      7.900000    6.900000    4.000000

# %%
df.head()
# Out:
#     sl   pl   pw  flower_type
# 0  4.6  1.5  0.2  Iris-setosa
# 1  5.4  1.7  0.4  Iris-setosa
# 2  4.6  1.4  0.3  Iris-setosa
# 3  5.0  1.5  0.2  Iris-setosa
# 4  4.4  1.4  0.2  Iris-setosa

# %% [markdown]
# ## Reset Df

# %%
#reset df
df=iris.copy()
#columns changing statement
df.columns=['sl','sw','pl','pw','flower_type']
df.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %% [markdown]
# ## To add new column

# %%
#to add new column which is difference of pl and pw
df['diff_pl_pw']=df['pl']-df['pw']
df.head()
# Out:
#     sl   sw   pl   pw  flower_type  diff_pl_pw
# 0  4.9  3.0  1.4  0.2  Iris-setosa         1.2
# 1  4.7  3.2  1.3  0.2  Iris-setosa         1.1
# 2  4.6  3.1  1.5  0.2  Iris-setosa         1.3
# 3  5.0  3.6  1.4  0.2  Iris-setosa         1.2
# 4  5.4  3.9  1.7  0.4  Iris-setosa         1.3

# %% [markdown]
# ### How to deal with Na

# %%
df.iloc[2:4,1:3]=np.nan
df.head()
# Out:
#     sl   sw   pl   pw  flower_type  diff_pl_pw
# 0  4.9  3.0  1.4  0.2  Iris-setosa         1.2
# 1  4.7  3.2  1.3  0.2  Iris-setosa         1.1
# 2  4.6  NaN  NaN  0.2  Iris-setosa         1.3
# 3  5.0  NaN  NaN  0.2  Iris-setosa         1.2
# 4  5.4  3.9  1.7  0.4  Iris-setosa         1.3

# %%
df.describe()
# Out:
#                sl          sw          pl          pw  diff_pl_pw
# count  149.000000  147.000000  147.000000  149.000000  149.000000
# mean     5.848322    3.046939    3.806122    1.205369    2.569128
# std      0.828594    0.434048    1.750351    0.761292    1.047707
# min      4.300000    2.000000    1.000000    0.100000    0.800000
# 25%      5.100000    2.800000    1.600000    0.300000    1.400000
# 50%      5.800000    3.000000    4.400000    1.300000    2.900000
# 75%      6.400000    3.300000    5.100000    1.800000    3.300000
# max      7.900000    4.400000    6.900000    2.500000    4.700000

# %% [markdown]
# ### First way to drop that whole row where NaN is present

# %%
#how to deal with NaN
df.dropna() #it drop whol row
# Out:
#       sl   sw   pl   pw     flower_type  diff_pl_pw
# 0    4.9  3.0  1.4  0.2     Iris-setosa         1.2
# 1    4.7  3.2  1.3  0.2     Iris-setosa         1.1
# 4    5.4  3.9  1.7  0.4     Iris-setosa         1.3
# 5    4.6  3.4  1.4  0.3     Iris-setosa         1.1
# 6    5.0  3.4  1.5  0.2     Iris-setosa         1.3
# ..   ...  ...  ...  ...             ...         ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica         2.9
# 145  6.3  2.5  5.0  1.9  Iris-virginica         3.1
# 146  6.5  3.0  5.2  2.0  Iris-virginica         3.2
# 147  6.2  3.4  5.4  2.3  Iris-virginica         3.1
# 148  5.9  3.0  5.1  1.8  Iris-virginica         3.3
#
# [147 rows x 6 columns]

# %%
df.head()
# Out:
#     sl   sw   pl   pw  flower_type  diff_pl_pw
# 0  4.9  3.0  1.4  0.2  Iris-setosa         1.2
# 1  4.7  3.2  1.3  0.2  Iris-setosa         1.1
# 2  4.6  NaN  NaN  0.2  Iris-setosa         1.3
# 3  5.0  NaN  NaN  0.2  Iris-setosa         1.2
# 4  5.4  3.9  1.7  0.4  Iris-setosa         1.3

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type  diff_pl_pw
# 0  4.9  3.0  1.4  0.2  Iris-setosa         1.2
# 1  4.7  3.2  1.3  0.2  Iris-setosa         1.1
# 2  4.6  NaN  NaN  0.2  Iris-setosa         1.3
# 3  5.0  NaN  NaN  0.2  Iris-setosa         1.2
# 4  5.4  3.9  1.7  0.4  Iris-setosa         1.3

# %% [markdown]
# ## Second way is to fill them with the mean of that particular column

# %%
df.sw.fillna(df.sw.mean(), inplace=True)
df.pl.fillna(df.pl.mean(), inplace=True)

# %%
df.head()
# Out:
#     sl        sw        pl   pw  flower_type  diff_pl_pw
# 0  4.9  3.000000  1.400000  0.2  Iris-setosa         1.2
# 1  4.7  3.200000  1.300000  0.2  Iris-setosa         1.1
# 2  4.6  3.046939  3.806122  0.2  Iris-setosa         1.3
# 3  5.0  3.046939  3.806122  0.2  Iris-setosa         1.2
# 4  5.4  3.900000  1.700000  0.4  Iris-setosa         1.3

# %% [markdown]
# ## Handling with String

# %%
df['Gender']='Female'
df.iloc[0:10,6]='Male'

def f(s):
    if s=='Male':
        return 0
    else:
        return 1
df['Sex']=df.Gender.apply(f)

# %%
df.head(15)
# Out:
#      sl        sw        pl   pw  flower_type  diff_pl_pw  Gender  Sex
# 0   4.9  3.000000  1.400000  0.2  Iris-setosa         1.2    Male    0
# 1   4.7  3.200000  1.300000  0.2  Iris-setosa         1.1    Male    0
# 2   4.6  3.046939  3.806122  0.2  Iris-setosa         1.3    Male    0
# 3   5.0  3.046939  3.806122  0.2  Iris-setosa         1.2    Male    0
# 4   5.4  3.900000  1.700000  0.4  Iris-setosa         1.3    Male    0
# 5   4.6  3.400000  1.400000  0.3  Iris-setosa         1.1    Male    0
# 6   5.0  3.400000  1.500000  0.2  Iris-setosa         1.3    Male    0
# 7   4.4  2.900000  1.400000  0.2  Iris-setosa         1.2    Male    0
# 8   4.9  3.100000  1.500000  0.1  Iris-setosa         1.4    Male    0
# 9   5.4  3.700000  1.500000  0.2  Iris-setosa         1.3    Male    0
# 10  4.8  3.400000  1.600000  0.2  Iris-setosa         1.4  Female    1
# 11  4.8  3.000000  1.400000  0.1  Iris-setosa         1.3  Female    1
# ...

# %%
del df['Gender']

# %%
df.head()
# Out:
#     sl        sw        pl   pw  flower_type  diff_pl_pw  Sex
# 0  4.9  3.000000  1.400000  0.2  Iris-setosa         1.2    0
# 1  4.7  3.200000  1.300000  0.2  Iris-setosa         1.1    0
# 2  4.6  3.046939  3.806122  0.2  Iris-setosa         1.3    0
# 3  5.0  3.046939  3.806122  0.2  Iris-setosa         1.2    0
# 4  5.4  3.900000  1.700000  0.4  Iris-setosa         1.3    0
